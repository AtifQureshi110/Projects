# %% [markdown]
# <a href="https://colab.research.google.com/github/AtifQureshi110/Projects/blob/main/TEXT_TO_VIDEO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this project, I made videos using specific prompts. I used tools like snapshot_download from Hugging Face Hub, pipeline from modelscope.pipelines, OutputKeys from modelscope.outputs, and pathlib. The model i usesd is called "damo-vilab/modelscope-damo-text-to-video-synthesis," and it works through a process called "text-to-video-synthesis." Once everything was set up, I just give it a written prompt, and the model created the video based on that written prompt.

# %%
# !pip install modelscope==1.4.2 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 kB 29.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 62.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.4/283.4 kB 36.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 32.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 13.7 MB/s eta 0:00:00
# ...

# %%
# !pip install open_clip_torch -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 36.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 51.6 MB/s eta 0:00:00

# %%
# !pip install pytorch-lightning -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.3/802.3 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 18.9 MB/s eta 0:00:00

# %%
import pickle
import pathlib
from huggingface_hub import snapshot_download
from modelscope.pipelines import pipeline
from modelscope.outputs import OutputKeys
# Out:
# 2024-05-31 04:54:44,186 - modelscope - INFO - PyTorch version 2.3.0+cu121 Found.
# 2024-05-31 04:54:44,193 - modelscope - INFO - TensorFlow version 2.15.0 Found.
# 2024-05-31 04:54:44,195 - modelscope - INFO - Loading ast index from /root/.cache/modelscope/ast_indexer
# 2024-05-31 04:54:44,198 - modelscope - INFO - No valid ast index found from /root/.cache/modelscope/ast_indexer, generating ast index from prebuilt!
# 2024-05-31 04:54:44,264 - modelscope - INFO - Loading done! Current index file version is 1.4.2, with md5 6cf0aca6e7b3e11f53e1badddb3609c1 and a total number of 842 components indexed

# %%
# Download the model snapshot
model_dir = pathlib.Path('weights')
snapshot_download('damo-vilab/modelscope-damo-text-to-video-synthesis', repo_type='model', local_dir=model_dir)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# configuration.json:   0%|          | 0.00/1.07k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.49k [00:00<?, ?B/s]
# VQGAN_autoencoder.pth:   0%|          | 0.00/5.21G [00:00<?, ?B/s]
# open_clip_pytorch_model.bin:   0%|          | 0.00/3.94G [00:00<?, ?B/s]
# text2video_pytorch_model.pth:   0%|          | 0.00/5.65G [00:00<?, ?B/s]
# ...

# %%
# Load the pipeline
pipe = pipeline('text-to-video-synthesis', model_dir.as_posix())
# Out:
# 2024-05-31 04:58:37,303 - modelscope - INFO - initiate model from weights
# 2024-05-31 04:58:37,305 - modelscope - INFO - initiate model from location weights.
# 2024-05-31 04:58:37,308 - modelscope - INFO - initialize model from weights
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2024-05-31 05:00:29,030 - modelscope - WARNING - No preprocessor field found in cfg.
# 2024-05-31 05:00:29,032 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2024-05-31 05:00:29,033 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': 'weights'}. trying to build by task and model information.
# ...

# %%
test_text = {
        'text': 'A panda eating bamboo on a rock.',
    }
output_video_path = pipe(test_text,)[OutputKeys.OUTPUT_VIDEO]
print('output_video_path:', output_video_path)
# Out:
# 2024-05-31 05:00:41,112 - modelscope - WARNING - task text-to-video-synthesis input definition is missing
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# 2024-05-31 05:01:38,849 - modelscope - WARNING - task text-to-video-synthesis output keys are missing
# output_video_path: /tmp/tmpa09wuved.mp4

# %%
from google.colab import files

# Assuming output_video_path is the correct path to your video file
files.download(output_video_path)

# %%
test_text = {
        'text': 'A boy walking in landon.',
    }
output_video_path = pipe(test_text,)[OutputKeys.OUTPUT_VIDEO]
print('output_video_path:', output_video_path)
# Out:
# 2024-05-31 05:02:05,835 - modelscope - WARNING - task text-to-video-synthesis input definition is missing
# 2024-05-31 05:03:02,151 - modelscope - WARNING - task text-to-video-synthesis output keys are missing
# output_video_path: /tmp/tmpyq4eonl3.mp4

# %%
# Assuming output_video_path is the correct path to your video file
files.download(output_video_path)

# %%
test_text = {
        'text': 'flag of pakistan at mountain',
    }
output_video_path = pipe(test_text,)[OutputKeys.OUTPUT_VIDEO]
print('output_video_path:', output_video_path)
# Out:
# 2024-05-31 05:04:52,329 - modelscope - WARNING - task text-to-video-synthesis input definition is missing
# 2024-05-31 05:05:48,365 - modelscope - WARNING - task text-to-video-synthesis output keys are missing
# output_video_path: /tmp/tmpnl8rdw2m.mp4

# %%
# Assuming output_video_path is the correct path to your video file
files.download(output_video_path)
